# %%
import langchain

# %%
from langchain.llms import OpenAI

# %%
mykey = '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'

# %%
client = OpenAI(api_key=mykey)
# Out:
# F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(

# %% [markdown]
# ### Prompt Templates

# %%
from langchain.prompts import PromptTemplate

# %%
prompt_template_name = PromptTemplate(
    input_variables=['country'],
    template='can you tell me the capital of {country}?'
)

# %%
prompt1= prompt_template_name.format(country='India')
prompt1
# Out:
# 'can you tell me the capital of India?'

# %%
prompt2 = prompt_template_name.format(country='China')
prompt2
# Out:
# 'can you tell me the capital of China?'

# %% [markdown]
# #### Another way

# %%
prompt_temp = PromptTemplate.from_template("what is a good name for a company that makes a {product}")

# %%
prompt3 = prompt_temp.format(product='toys')
prompt3
# Out:
# 'what is a good name for a company that makes a toys'

# %% [markdown]
# ### Agent

# %%
prompt4 = 'can you tell me who won the recent world cup?'

# %%
client.predict(prompt4)
# Out:
# F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `predict` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 client.predict(prompt4)
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\language_models\llms.py:1032, in BaseLLM.predict(self, text, stop, **kwargs)
#    1030 else:
#    1031     _stop = list(stop)
# -> 1032 return self(text, stop=_stop, **kwargs)
#
# ...

# %% [markdown]
# for extracting a real-time info i'm going to use serp API
#
# now by using the serp API i'll call google-search-engine
#
# and i'll extract the information in a real time

# %% [markdown]
# ##### pip install google-search-results

# %%
serpapi_key = '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'

# %%
from langchain.agents import AgentType, load_tools, initialize_agent

from langchain.llms import OpenAI

# %%
client=OpenAI(api_key=mykey)

# %%
tool = load_tools(['serpapi'], serpapi_api_key = serpapi_key, llm=client)

# %%
agent = initialize_agent(tool, client, agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION,verbose=True)
# Out:
# F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `initialize_agent` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use Use new agent constructor methods like create_react_agent, create_json_agent, create_structured_chat_agent, etc. instead.
#   warn_deprecated(

# %%
agent.run("can you tell who won the cricket worldcup recently?")
# Out:
# F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 agent.run("can you tell who won the cricket worldcup recently?")
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain\chains\base.py:550, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
# ...

# %% [markdown]
# ##### pip install wikipedia

# %%
tool = load_tools(['wikipedia'], llm=client)

# %%
agent = initialize_agent(tool, client, agent=AgentType.ZERO_SHOT_REACT_DESCRIPTION, verbose=True)

# %%
agent.run("can you tell who won the cricket worldcup recently?")
# Out:
# > Entering new AgentExecutor chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 agent.run("can you tell who won the cricket worldcup recently?")
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain\chains\base.py:550, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     548     if len(args) != 1:
#     549         raise ValueError("`run` supports only one positional argument.")
# --> 550     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     551         _output_key
#     552     ]
# ...

# %% [markdown]
# ### Chain

# %%
client
# Out:
# OpenAI(client=<openai.resources.completions.Completions object at 0x000002288119A3D0>, async_client=<openai.resources.completions.AsyncCompletions object at 0x00000228826F8430>, openai_api_key='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', openai_proxy='')

# %%
from langchain.prompts import PromptTemplate

prompt = PromptTemplate.from_template("What is a good name for a company that makes {product}")

# %%
from langchain.chains import LLMChain

# %%
chain = LLMChain(llm = client, prompt = prompt)

# %%
chain.run("Wine")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 chain.run("Wine")
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain\chains\base.py:550, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     548     if len(args) != 1:
#     549         raise ValueError("`run` supports only one positional argument.")
# --> 550     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     551         _output_key
#     552     ]
#     554 if kwargs and not args:
# ...

# %% [markdown]
# ## Example2

# %%
prompt_template = PromptTemplate(
    input_variables=['cuisine'],
    template="I want to open a restaurant for {cuisine} food, suggest a fancy name for this"
)

# %%
prompt_template
# Out:
# PromptTemplate(input_variables=['cuisine'], template='I want to open a restaurant for {cuisine} food, suggest a fancy name for this')

# %%
chain = LLMChain(llm=client, prompt=prompt_template)

# %%
chain.run("chinese").strip()
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 chain.run("chinese").strip()
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain\chains\base.py:550, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     548     if len(args) != 1:
#     549         raise ValueError("`run` supports only one positional argument.")
# --> 550     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     551         _output_key
#     552     ]
#     554 if kwargs and not args:
# ...

# %% [markdown]
# if we want to combine multiple chain and set a sequence for that we use simple sequential chain

# %%
prompt_template_name = PromptTemplate(
    input_variables=['startup_name'],
    template="I want to start a startup for {startup-name}, suggest me a good name for this"
)

# %%
name_chain = LLMChain(llm=client, prompt=prompt_template_name)

# %%
prompt_template_items = PromptTemplate(
    input_variables=['name'],
    template = "suggest some strategies for {name}"
)

# %%
strategies_chain = LLMChain(llm=client, prompt=prompt_template_items)

# %%
from langchain.chains import SimpleSequentialChain

# %%
chain = SimpleSequentialChain(chains=[name_chain, strategies_chain])

# %%
chain.run("Artificial Intelligence")
# Out:
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 chain.run("Artificial Intelligence")
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain\chains\base.py:550, in Chain.run(self, callbacks, tags, metadata, *args, **kwargs)
#     548     if len(args) != 1:
#     549         raise ValueError("`run` supports only one positional argument.")
# --> 550     return self(args[0], callbacks=callbacks, tags=tags, metadata=metadata)[
#     551         _output_key
#     552     ]
#     554 if kwargs and not args:
# ...

# %% [markdown]
# Now lets try to understand the sequential chain

# %%
prompt_template_name = PromptTemplate(
    input_variables=['cuisine'],
    template="I want to open a restaurant for {cuisine} food, suggest a fancy name for this"
)

name_chain = LLMChain(llm=client, prompt=prompt_template_name, output_key='restaurant_name')

# %%
prompt_templates_items = PromptTemplate(
    input_variables=['restaurant_name'],
    template = 'suggest some menu items for {restaurant_name}'
)

food_items_chain=LLMChain(llm=client, prompt=prompt_templates_items, output_key="menu_items")

# %%
from langchain.chains import SequentialChain

# %%
chain = SequentialChain(chains=[name_chain, food_items_chain],
                        input_variables=['cuisine'],
                        output_variables=['restaurant_name', 'menu_items']
                       )

# %%
chain({'cuisine':'indian'})
# Out:
# F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:117: LangChainDeprecationWarning: The function `__call__` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# Cell In[74], line 1
# ----> 1 chain({'cuisine':'indian'})
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain_core\_api\deprecation.py:145, in deprecated.<locals>.deprecate.<locals>.warning_emitting_wrapper(*args, **kwargs)
#     143     warned = True
#     144     emit_warning()
# --> 145 return wrapped(*args, **kwargs)
#
# File F:\Anaconda3\envs\testingopenai\lib\site-packages\langchain\chains\base.py:383, in Chain.__call__(self, inputs, return_only_outputs, callbacks, tags, metadata, run_name, include_run_info)
#     351 """Execute the chain.
#     352
# ...

# %% [markdown]
# ### Document Loaders

# %%
### Day5 till 15:00
